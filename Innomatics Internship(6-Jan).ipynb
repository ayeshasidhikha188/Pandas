# %%
import pandas as pd

# %%
links=pd.read_csv(r"C:\Users\mdimr\Downloads\movie_data\links.csv")

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies=pd.read_csv(r"C:\Users\mdimr\Downloads\movie_data\movies.csv")

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings=pd.read_csv(r"C:\Users\mdimr\Downloads\movie_data\ratings.csv")

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags=pd.read_csv(r"C:\Users\mdimr\Downloads\movie_data\tags.csv")

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %% [markdown]
# ### What is the shape of "movies.csv"

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# ### What is the shape of "ratings.csv"?

# %%
ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# ### How many unique "userId" are available in "ratings.csv"?

# %%
ratings['userId'].nunique()
# Out:
# 610

# %% [markdown]
# ### Which movie has recieved maximum number of user ratings?

# %%
z=pd.merge(movies,ratings)
z
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
y=pd.merge(z,tags,on='userId',how='inner')
y
# Out:
#          movieId_x                                title  \
# 0                1                     Toy Story (1995)
# 1               50           Usual Suspects, The (1995)
# 2               58    Postman, The (Postino, Il) (1994)
# 3              150                     Apollo 13 (1995)
# 4              165    Die Hard: With a Vengeance (1995)
# ...            ...                                  ...
# 4626861     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626862     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626863     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626864     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626865     193587  Bungo Stray Dogs: Dead Apple (2018)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       7     4.5
# 1                             Crime|Mystery|Thriller       7     4.5
# 2                               Comedy|Drama|Romance       7     3.0
# ...

# %%
z['rating'].max()
# Out:
# 5.0

# %%
z['genres'].max()
# Out:
# 'Western'

# %%
z.groupby(['rating'])[['userId','movieId','title']].max()
# Out:
#         userId  movieId                                      title
# rating
# 0.5        610   184641                                 xXx (2002)
# 1.0        610   190221  À nous la liberté (Freedom for Us) (1931)
# 1.5        610   190215             xXx: State of the Union (2005)
# 2.0        610   185033                      ¡Three Amigos! (1986)
# 2.5        610   189713                      ¡Three Amigos! (1986)
# 3.0        610   193567                      ¡Three Amigos! (1986)
# 3.5        610   193587                      ¡Three Amigos! (1986)
# 4.0        610   193609                      ¡Three Amigos! (1986)
# 4.5        610   191005                            eXistenZ (1999)
# 5.0        610   187717                      ¡Three Amigos! (1986)

# %%
z[z['movieId']==184641]
# Out:
#         movieId                            title                    genres  \
# 100759   184641  Fullmetal Alchemist 2018 (2017)  Action|Adventure|Fantasy
#
#         userId  rating   timestamp
# 100759     184     0.5  1537094808

# %%
h=y[y['title']== "Matrix, The (1999)"]
h
# Out:
#          movieId_x               title                  genres  userId  \
# 2776          2571  Matrix, The (1999)  Action|Sci-Fi|Thriller      18
# 2777          2571  Matrix, The (1999)  Action|Sci-Fi|Thriller      18
# 2778          2571  Matrix, The (1999)  Action|Sci-Fi|Thriller      18
# 2779          2571  Matrix, The (1999)  Action|Sci-Fi|Thriller      18
# 2780          2571  Matrix, The (1999)  Action|Sci-Fi|Thriller      18
# ...            ...                 ...                     ...     ...
# 4618071       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 4618072       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 4618073       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 4618074       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 4618075       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#          rating  timestamp_x  movieId_y           tag  timestamp_y
# ...

# %%
h[h['tag']=='philosophy']
# Out:
#          movieId_x               title                  genres  userId  \
# 3835806       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     599
# 4617985       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 4618028       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#          rating  timestamp_x  movieId_y         tag  timestamp_y
# 3835806     5.0   1519029461       2959  philosophy   1498456898
# 4617985     4.0   1424141086       2571  philosophy   1424141098
# 4618028     4.0   1424141086      79132  philosophy   1424140124

# %%
h[h['tag']=='alternate universe']
# Out:
#          movieId_x               title                  genres  userId  \
# 1170919       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1171085       2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
#
#          rating  timestamp_x  movieId_y                 tag  timestamp_y
# 1170919     4.5   1053020932       1680  alternate universe   1138031846
# 1171085     4.5   1053020932       2571  alternate universe   1137204991

# %%
h[h['tag']=='karate']# no
# Out:
# Empty DataFrame
# Columns: [movieId_x, title, genres, userId, rating, timestamp_x, movieId_y, tag, timestamp_y]
# Index: []

# %%
z.groupby('userId')['rating'].nunique()
# Out:
# userId
# 1       5
# 2       7
# 3       7
# 4       5
# 5       5
#        ..
# 606    10
# 607     5
# 608    10
# 609     2
# 610    10
# Name: rating, Length: 610, dtype: int64

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies['title'].unique()
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        ..., 'Flint (2017)', 'Bungo Stray Dogs: Dead Apple (2018)',
#        'Andrew Dice Clay: Dice Rules (1991)'], dtype=object)

# %%
movies['genres'].unique()
# Out:
# array(['Adventure|Animation|Children|Comedy|Fantasy',
#        'Adventure|Children|Fantasy', 'Comedy|Romance',
#        'Comedy|Drama|Romance', 'Comedy', 'Action|Crime|Thriller',
#        'Adventure|Children', 'Action', 'Action|Adventure|Thriller',
#        'Comedy|Horror', 'Adventure|Animation|Children', 'Drama',
#        'Action|Adventure|Romance', 'Crime|Drama', 'Drama|Romance',
#        'Action|Comedy|Crime|Drama|Thriller', 'Comedy|Crime|Thriller',
#        'Crime|Drama|Horror|Mystery|Thriller', 'Drama|Sci-Fi',
#        'Children|Drama', 'Adventure|Drama|Fantasy|Mystery|Sci-Fi',
#        'Mystery|Sci-Fi|Thriller', 'Children|Comedy', 'Drama|War',
#        'Action|Crime|Drama', 'Action|Adventure|Fantasy',
#        'Comedy|Drama|Thriller', 'Mystery|Thriller',
#        'Animation|Children|Drama|Musical|Romance',
#        'Crime|Mystery|Thriller', 'Adventure|Drama', 'Drama|Thriller',
#        'Comedy|Crime', 'Action|Sci-Fi|Thriller',
# ...

# %%
movies['genres']=movies['genres'].str.replace('|',' ')

# %%
movies['genres']
# Out:
# 0       Adventure Animation Children Comedy Fantasy
# 1                        Adventure Children Fantasy
# 2                                    Comedy Romance
# 3                              Comedy Drama Romance
# 4                                            Comedy
#                            ...
# 9737                Action Animation Comedy Fantasy
# 9738                       Animation Comedy Fantasy
# 9739                                          Drama
# 9740                               Action Animation
# 9741                                         Comedy
# Name: genres, Length: 9742, dtype: object

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags['tag'].unique()
# Out:
# array(['funny', 'Highly quotable', 'will ferrell', ..., 'gun fu',
#        'heroic bloodshed', 'Heroic Bloodshed'], dtype=object)

# %%
links.columns
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
y
# Out:
#          movieId_x                                title  \
# 0                1                     Toy Story (1995)
# 1               50           Usual Suspects, The (1995)
# 2               58    Postman, The (Postino, Il) (1994)
# 3              150                     Apollo 13 (1995)
# 4              165    Die Hard: With a Vengeance (1995)
# ...            ...                                  ...
# 4626861     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626862     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626863     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626864     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626865     193587  Bungo Stray Dogs: Dead Apple (2018)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       7     4.5
# 1                             Crime|Mystery|Thriller       7     4.5
# 2                               Comedy|Drama|Romance       7     3.0
# ...

# %%
z[z['title']== "Fight Club (1999)"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
y[y['title']== "Terminator 2: Judgment Day (1991)"].count()
# Out:
# movieId_x      2576
# title          2576
# genres         2576
# userId         2576
# rating         2576
# timestamp_x    2576
# movieId_y      2576
# tag            2576
# timestamp_y    2576
# dtype: int64

# %%
y[y['title']== "Terminator 2: Judgment Day (1991)"].sum()
# Out:
# movieId_x                                                1517264
# title          Terminator 2: Judgment Day (1991)Terminator 2:...
# genres         Action|Sci-FiAction|Sci-FiAction|Sci-FiAction|...
# userId                                                   1215971
# rating                                                   10220.5
# timestamp_x                                        3152307180119
# movieId_y                                               31071620
# tag            way too longAl PacinogangstermafiaAl PacinoMaf...
# timestamp_y                                        3209712211876
# dtype: object

# %%
10220.5/2576
# Out:
# 3.967585403726708

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure Animation Children Comedy Fantasy
# 1                      Adventure Children Fantasy
# 2                                  Comedy Romance
# 3                            Comedy Drama Romance
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
z
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
y[y['title']=='Shawshank Redemption']
# Out:
# Empty DataFrame
# Columns: [movieId_x, title, genres, userId, rating, timestamp_x, movieId_y, tag, timestamp_y]
# Index: []

# %%
y[y['genres']=='Shawshank Redemption']
# Out:
# Empty DataFrame
# Columns: [movieId_x, title, genres, userId, rating, timestamp_x, movieId_y, tag, timestamp_y]
# Index: []

# %%
y[y['tag']=='Matrix']
# Out:
#          movieId_x                                      title  \
# 4381013          2                             Jumanji (1995)
# 4381383          6                                Heat (1995)
# 4381753         47                Seven (a.k.a. Se7en) (1995)
# 4382123        110                          Braveheart (1995)
# 4382493        260  Star Wars: Episode IV - A New Hope (1977)
# ...            ...                                        ...
# 4514583     184471                         Tomb Raider (2018)
# 4514953     185031                               Alpha (2018)
# 4515323     185135          Sherlock - A Study in Pink (2010)
# 4515693     187593                          Deadpool 2 (2018)
# 4516063     187595             Solo: A Star Wars Story (2018)
#
#                                    genres  userId  rating  timestamp_x  \
# 4381013        Adventure|Children|Fantasy      62     4.0   1528843890
# 4381383             Action|Crime|Thriller      62     4.5   1522190219
# ...

# %%
y[y['tag']=='Shawshank Redemption']
# Out:
# Empty DataFrame
# Columns: [movieId_x, title, genres, userId, rating, timestamp_x, movieId_y, tag, timestamp_y]
# Index: []

# %%
z.groupby('userId')['movieId'].max()
# Out:
# userId
# 1        5060
# 2      131724
# 3       72378
# 4        4967
# 5         608
#         ...
# 606     98243
# 607      5060
# 608     54503
# 609      1161
# 610    170875
# Name: movieId, Length: 610, dtype: int64

# %%
h=z[z['movieId']==47]
h
# Out:
#       movieId                        title            genres  userId  rating  \
# 2107       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller       1     5.0
# 2108       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller       4     2.0
# 2109       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller       6     4.0
# 2110       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller       8     4.0
# 2111       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller      13     5.0
# ...       ...                          ...               ...     ...     ...
# 2305       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller     601     4.0
# 2306       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller     602     5.0
# 2307       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller     606     3.0
# 2308       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller     608     4.5
# 2309       47  Seven (a.k.a. Se7en) (1995)  Mystery|Thriller     610     5.0
#
#        timestamp
# 2107   964983815
# ...

# %%
h["title"]
# Out:
# 2107    Seven (a.k.a. Se7en) (1995)
# 2108    Seven (a.k.a. Se7en) (1995)
# 2109    Seven (a.k.a. Se7en) (1995)
# 2110    Seven (a.k.a. Se7en) (1995)
# 2111    Seven (a.k.a. Se7en) (1995)
#                    ...
# 2305    Seven (a.k.a. Se7en) (1995)
# 2306    Seven (a.k.a. Se7en) (1995)
# 2307    Seven (a.k.a. Se7en) (1995)
# 2308    Seven (a.k.a. Se7en) (1995)
# 2309    Seven (a.k.a. Se7en) (1995)
# Name: title, Length: 203, dtype: object

# %%
y[y['title']== "Terminator 2: Judgment Day (1991)"].sum()
# Out:
# movieId_x                                                1517264
# title          Terminator 2: Judgment Day (1991)Terminator 2:...
# genres         Action|Sci-FiAction|Sci-FiAction|Sci-FiAction|...
# userId                                                   1215971
# rating                                                   10220.5
# timestamp_x                                        3152307180119
# movieId_y                                               31071620
# tag            way too longAl PacinogangstermafiaAl PacinoMaf...
# timestamp_y                                        3209712211876
# dtype: object

# %%
(10220.5/2576)*100
# Out:
# 396.75854037267084

# %% [markdown]
# ### IMPORTANT NOTE 1

# %%
z
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %% [markdown]
# ### Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.

# %%
df=z.groupby(['userId','movieId'])['rating'].agg(['count','mean'])
df
# Out:
#                 count  mean
# userId movieId
# 1      1            1   4.0
#        3            1   4.0
#        6            1   4.0
#        47           1   5.0
#        50           1   5.0
# ...               ...   ...
# 610    166534       1   4.0
#        168248       1   5.0
#        168250       1   5.0
#        168252       1   5.0
#        170875       1   3.0
#
# [100836 rows x 2 columns]

# %% [markdown]
# ### Apply inner join on dataframe created from movies.csv and the grouped df from step 1.

# %%
m=pd.merge(z,df,on='movieId',how='inner')
m
# Out:
#          movieId                                      title  \
# 0              1                           Toy Story (1995)
# 1              1                           Toy Story (1995)
# 2              1                           Toy Story (1995)
# 3              1                           Toy Story (1995)
# 4              1                           Toy Story (1995)
# ...          ...                                        ...
# 5924695   193581  Black Butler: Book of the Atlantic (2017)
# 5924696   193583               No Game No Life: Zero (2017)
# 5924697   193585                               Flint (2017)
# 5924698   193587        Bungo Stray Dogs: Dead Apple (2018)
# 5924699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1        Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# ...

# %% [markdown]
# ### Filter only those movies which have more than 50 user ratings (i.e. > 50).

# %%
x=m[m['userId']>50]
x
# Out:
#          movieId                                      title  \
# 3870           1                           Toy Story (1995)
# 3871           1                           Toy Story (1995)
# 3872           1                           Toy Story (1995)
# 3873           1                           Toy Story (1995)
# 3874           1                           Toy Story (1995)
# ...          ...                                        ...
# 5924695   193581  Black Butler: Book of the Atlantic (2017)
# 5924696   193583               No Game No Life: Zero (2017)
# 5924697   193585                               Flint (2017)
# 5924698   193587        Bungo Stray Dogs: Dead Apple (2018)
# 5924699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  userId  rating  \
# 3870     Adventure|Animation|Children|Comedy|Fantasy      54     3.0
# 3871     Adventure|Animation|Children|Comedy|Fantasy      54     3.0
# ...

# %% [markdown]
# ### Which movie is the most popular based on  average user ratings?

# %%
df=x.groupby(['userId','movieId'])['rating'].agg(['mean'])
df
# Out:
#                 mean
# userId movieId
# 51     2         4.5
#        3         4.0
#        7         4.0
#        36        3.0
#        65        3.5
# ...              ...
# 610    166534    4.0
#        168248    5.0
#        168250    5.0
#        168252    5.0
#        170875    3.0
#
# [93414 rows x 1 columns]

# %%
x=pd.pivot_table(m,
                 index=['movieId'],
                values=['rating'])

# %%
x
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# ...           ...
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193587   3.500000
# 193609   4.000000
#
# [9724 rows x 1 columns]

# %%
x=pd.pivot_table(m,
                 index=['movieId'],
                values=['rating']).idxmax().values[0]

# %%
x
# Out:
# 53

# %%
m[m['movieId']==53]
# Out:
#         movieId            title           genres  userId  rating  timestamp  \
# 294219       53  Lamerica (1994)  Adventure|Drama      85     5.0  889468268
# 294220       53  Lamerica (1994)  Adventure|Drama      85     5.0  889468268
# 294221       53  Lamerica (1994)  Adventure|Drama     603     5.0  963180003
# 294222       53  Lamerica (1994)  Adventure|Drama     603     5.0  963180003
#
#         count  mean
# 294219      1   5.0
# 294220      1   5.0
# 294221      1   5.0
# 294222      1   5.0

# %%
x
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# ...           ...
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193587   3.500000
# 193609   4.000000
#
# [9724 rows x 1 columns]

# %%
# not getting

# %%
x=m.groupby(['userId','title'])['rating'].value_counts().idxmax()
x
# Out:
# (1, 'Forrest Gump (1994)', 4.0)

# %%
m[m['rating']==5]
# Out:
#          movieId                             title  \
# 1935           1                  Toy Story (1995)
# 1936           1                  Toy Story (1995)
# 1937           1                  Toy Story (1995)
# 1938           1                  Toy Story (1995)
# 1939           1                  Toy Story (1995)
# ...          ...                               ...
# 5924654   187595    Solo: A Star Wars Story (2018)
# 5924655   187595    Solo: A Star Wars Story (2018)
# 5924656   187595    Solo: A Star Wars Story (2018)
# 5924657   187595    Solo: A Star Wars Story (2018)
# 5924658   187717  Won't You Be My Neighbor? (2018)
#
#                                               genres  userId  rating  \
# 1935     Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 1936     Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 1937     Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# 1938     Adventure|Animation|Children|Comedy|Fantasy      31     5.0
# ...

# %%
m[m['rating']==5].value_counts()
# Out:
# movieId  title                             genres        userId  rating  timestamp   count  mean
# 318      Shawshank Redemption, The (1994)  Crime|Drama   69      5.0     1021646944  1      5.0     153
#                                                          418     5.0     1461865563  1      5.0     153
#                                                          385     5.0     834691601   1      5.0     153
#                                                          83      5.0     1332839665  1      5.0     153
#                                                          80      5.0     1377308028  1      5.0     153
#                                                                                                    ...
# 2568     Mod Squad, The (1999)             Action|Crime  558     5.0     1035416048  1      5.0       1
#                                                                                             4.5       1
# ...

# %%
m[m['rating']==4].value_counts()
# Out:
# movieId  title                                genres           userId  rating  timestamp   count  mean
# 318      Shawshank Redemption, The (1994)     Crime|Drama      318     4.0     1443879880  1      5.0     153
#                                                                317     4.0     1430361381  1      5.0     153
#                                                                304     4.0     931811802   1      5.0     153
#                                                                300     4.0     1425351440  1      5.0     153
#                                                                284     4.0     832695208   1      5.0     153
#                                                                                                          ...
# 3285     Beach, The (2000)                    Adventure|Drama  558     4.0     1035416320  1      2.5       1
#                                                                606     4.0     1171365218  1      2.5       1
# ...

# %%
m['rating'].unique()
# Out:
# array([4. , 4.5, 2.5, 3.5, 3. , 5. , 0.5, 2. , 1.5, 1. ])

# %%
m[m['rating']==4]
# Out:
#          movieId                                      title  \
# 0              1                           Toy Story (1995)
# 1              1                           Toy Story (1995)
# 2              1                           Toy Story (1995)
# 3              1                           Toy Story (1995)
# 4              1                           Toy Story (1995)
# ...          ...                                        ...
# 5924684   190209         Jeff Ross Roasts the Border (2017)
# 5924692   193571                        Silver Spoon (2014)
# 5924693   193573    Love Live! The School Idol Movie (2015)
# 5924695   193581  Black Butler: Book of the Atlantic (2017)
# 5924699   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1        Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# ...

# %%
m[m['rating']==5].value_counts()
# Out:
# movieId  title                             genres        userId  rating  timestamp   count  mean
# 318      Shawshank Redemption, The (1994)  Crime|Drama   69      5.0     1021646944  1      5.0     153
#                                                          418     5.0     1461865563  1      5.0     153
#                                                          385     5.0     834691601   1      5.0     153
#                                                          83      5.0     1332839665  1      5.0     153
#                                                          80      5.0     1377308028  1      5.0     153
#                                                                                                    ...
# 2568     Mod Squad, The (1999)             Action|Crime  558     5.0     1035416048  1      5.0       1
#                                                                                             4.5       1
# ...

# %%
u.head()
# Out:
#                                      mean
# userId title
# 51     13th Warrior, The (1999)       3.5
#        1408 (2007)                    3.5
#        2001: A Space Odyssey (1968)   5.0
#        28 Days Later (2002)           5.0
#        300 (2007)                     5.0

# %%
m[m['title']=='Godfather, The (1972)'].sum()
# Out:
# movieId                                               31629312
# title        Godfather, The (1972)Godfather, The (1972)Godf...
# genres       Crime|DramaCrime|DramaCrime|DramaCrime|DramaCr...
# userId                                                10976064
# rating                                                158112.0
# timestamp                                       44814358544064
# count                                                    36864
# mean                                                  158112.0
# dtype: object

# %%
m[m['title']=='Godfather, The (1972)'].count()
# Out:
# movieId      36864
# title        36864
# genres       36864
# userId       36864
# rating       36864
# timestamp    36864
# count        36864
# mean         36864
# dtype: int64

# %%
(158112.0/36864)*100
# Out:
# 428.90625

# %%
m[m['title']=='Wolf of Wall Street, The (2013)'].count()
# Out:
# movieId      2916
# title        2916
# genres       2916
# userId       2916
# rating       2916
# timestamp    2916
# count        2916
# mean         2916
# dtype: int64

# %%
m[m['title']=='Wolf of Wall Street, The (2013)'].sum()
# Out:
# movieId                                              311376312
# title        Wolf of Wall Street, The (2013)Wolf of Wall St...
# genres       Comedy|Crime|DramaComedy|Crime|DramaComedy|Cri...
# userId                                                  877068
# rating                                                 11421.0
# timestamp                                        4304888292564
# count                                                     2916
# mean                                                   11421.0
# dtype: object

# %%
11421.0/2916
# Out:
# 3.9166666666666665

# %%
m[m['title']=='Jumanji (1995)'].sum()
# Out:
# movieId                                                  24200
# title        Jumanji (1995)Jumanji (1995)Jumanji (1995)Juma...
# genres       Adventure|Children|FantasyAdventure|Children|F...
# userId                                                 3987610
# rating                                                 41525.0
# timestamp                                       13743244165420
# count                                                    12100
# mean                                                   41525.0
# dtype: object

# %%
m[m['title']=='Jumanji (1995)'].count()
# Out:
# movieId      12100
# title        12100
# genres       12100
# userId       12100
# rating       12100
# timestamp    12100
# count        12100
# mean         12100
# dtype: int64

# %%
41525.0/12100
# Out:
# 3.4318181818181817

# %%
m[m['title']=='Shawshank Redemption, The (1994)'].count()
# Out:
# movieId      100489
# title        100489
# genres       100489
# userId       100489
# rating       100489
# timestamp    100489
# count        100489
# mean         100489
# dtype: int64

# %%
41525.0/100489
# Out:
# 0.4132293086805521

# %% [markdown]
# ### Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
u=m.groupby(['userId','title'])['rating'].agg(['count'])

# %%
u
# Out:
#                                              count
# userId title
# 1      13th Warrior, The (1999)                 26
#        20 Dates (1998)                           7
#        Abyss, The (1989)                        62
#        Adventures of Robin Hood, The (1938)      8
#        Alice in Wonderland (1951)               40
# ...                                            ...
# 610    [REC] (2007)                              8
#        [REC]² (2009)                             3
#        [REC]³ 3 Génesis (2012)                   2
#        xXx (2002)                               24
#        xXx: State of the Union (2005)            5
#
# [100832 rows x 1 columns]

# %%
u.head()
# Out:
#                                              count
# userId title
# 1      13th Warrior, The (1999)                 26
#        20 Dates (1998)                           7
#        Abyss, The (1989)                        62
#        Adventures of Robin Hood, The (1938)      8
#        Alice in Wonderland (1951)               40

# %%
df.max()
# Out:
# mean    5.0
# dtype: float64

# %%
w=m[m['title']=='Pulp Fiction (1994)']

# %%
w[w['rating']==5]
# Out:
#         movieId                title                       genres  userId  \
# 740240      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller       5
# 740241      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller       5
# 740242      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller       5
# 740243      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller       5
# 740244      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller       5
# ...         ...                  ...                          ...     ...
# 833870      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller     610
# 833871      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller     610
# 833872      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller     610
# 833873      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller     610
# 833874      296  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller     610
#
#         rating   timestamp  count  mean
# ...

# %%
t=m[m['title']=='Bad Boys (1995)']

# %%
t[t['rating']==5]
# Out:
#         movieId            title                              genres  userId  \
# 407665      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     162
# 407666      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     162
# 407667      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     162
# 407668      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     162
# 407669      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     162
# ...         ...              ...                                 ...     ...
# 408935      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     438
# 408936      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     438
# 408937      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     438
# 408938      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     438
# 408939      145  Bad Boys (1995)  Action|Comedy|Crime|Drama|Thriller     438
#
#         rating   timestamp  count  mean
# ...

# %%
m[m['title']=='Silence of the Lambs, The (1991)']
# Out:
#          movieId                             title                 genres  \
# 1788954      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1788955      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1788956      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1788957      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1788958      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# ...          ...                               ...                    ...
# 1866790      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866791      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866792      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866793      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866794      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
#
#          userId  rating   timestamp  count  mean
# ...

# %% [markdown]
# ### Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
m[m['title']=='Matrix, The (1999)']
# Out:
#          movieId               title                  genres  userId  rating  \
# 3653698     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653699     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653700     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653701     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653702     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# ...          ...                 ...                     ...     ...     ...
# 3730977     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730978     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730979     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730980     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730981     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
#
#           timestamp  count  mean
# ...

# %%
h=m[m['title']=='Matrix, The (1999)']

# %%
h[h['rating']==5]
# Out:
#          movieId               title                  genres  userId  rating  \
# 3653698     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653699     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653700     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653701     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# 3653702     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       1     5.0
# ...          ...                 ...                     ...     ...     ...
# 3730977     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730978     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730979     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730980     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
# 3730981     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     610     5.0
#
#           timestamp  count  mean
# ...

# %%
i=m[m['title']=='Silence of the Lambs, The (1991)']

# %%
i[i['rating']==5]
# Out:
#          movieId                             title                 genres  \
# 1789233      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1789234      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1789235      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1789236      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1789237      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# ...          ...                               ...                    ...
# 1866232      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866233      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866234      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866235      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
# 1866236      593  Silence of the Lambs, The (1991)  Crime|Horror|Thriller
#
#          userId  rating  timestamp  count  mean
# ...

# %%
m['title'].unique()
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        ..., 'Flint (2017)', 'Bungo Stray Dogs: Dead Apple (2018)',
#        'Andrew Dice Clay: Dice Rules (1991)'], dtype=object)

# %%
i=m[m['title']=='Deadpool (2016)']

# %%
i[i['rating']==5]
# Out:
#          movieId            title                          genres  userId  \
# 5899263   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      30
# 5899264   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      30
# 5899265   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      30
# 5899266   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      30
# 5899267   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      30
# ...          ...              ...                             ...     ...
# 5901688   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     550
# 5901689   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     550
# 5901690   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     550
# 5901691   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     550
# 5901692   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     550
#
#          rating   timestamp  count  mean
# ...

# %%
i[i['rating']==4.5]
# Out:
#          movieId            title                          genres  userId  \
# 5899479   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      62
# 5899480   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      62
# 5899481   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      62
# 5899482   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      62
# 5899483   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      62
# ...          ...              ...                             ...     ...
# 5900446   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     249
# 5900447   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     249
# 5900448   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     249
# 5900449   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     249
# 5900450   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     249
#
#          rating   timestamp  count  mean
# ...

# %%
i[i['rating']==4]
# Out:
#          movieId            title                          genres  userId  \
# 5899587   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      68
# 5899588   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      68
# 5899589   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      68
# 5899590   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      68
# 5899591   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi      68
# ...          ...              ...                             ...     ...
# 5901904   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     596
# 5901905   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     596
# 5901906   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     596
# 5901907   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     596
# 5901908   122904  Deadpool (2016)  Action|Adventure|Comedy|Sci-Fi     596
#
#          rating   timestamp  count  mean
# ...

# %%
i=m[m['title']=='Terminator 2: Judgment Day (1991)']

# %%
i[i['rating']==5]
# Out:
#          movieId                              title         genres  userId  \
# 1677057      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# 1677058      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# 1677059      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# 1677060      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# 1677061      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      15
# ...          ...                                ...            ...     ...
# 1726332      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
# 1726333      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
# 1726334      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
# 1726335      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
# 1726336      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     610
#
#          rating   timestamp  count  mean
# ...

# %%
i[i['rating']==4.5]
# Out:
#          movieId                              title         genres  userId  \
# 1677281      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      17
# 1677282      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      17
# 1677283      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      17
# 1677284      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      17
# 1677285      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      17
# ...          ...                                ...            ...     ...
# 1724540      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     599
# 1724541      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     599
# 1724542      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     599
# 1724543      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     599
# 1724544      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     599
#
#          rating   timestamp  count  mean
# ...

# %%
i[i['rating']==4]
# Out:
#          movieId                              title         genres  userId  \
# 1676833      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 1676834      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 1676835      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 1676836      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# 1676837      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi      11
# ...          ...                                ...            ...     ...
# 1725660      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 1725661      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 1725662      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 1725663      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
# 1725664      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     607
#
#          rating  timestamp  count  mean
# ...

# %%
i=m[m['title']=='X-Men: The Last Stand (2006)']

# %%
i[i['rating']==5]
# Out:
#          movieId                         title                  genres  \
# 5413103    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413104    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413105    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413106    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413107    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# ...          ...                           ...                     ...
# 5415386    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415387    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415388    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415389    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415390    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
#
#          userId  rating   timestamp  count  mean
# 5413103      34     5.0  1162050637      1   4.0
# ...

# %%
i[i['rating']==4.5]
# Out:
#          movieId                         title                  genres  \
# 5413363    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413364    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413365    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413366    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5413367    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# ...          ...                           ...                     ...
# 5415334    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415335    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415336    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415337    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415338    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
#
#          userId  rating   timestamp  count  mean
# 5413363     129     4.5  1167376478      1   4.0
# ...

# %%
i[i['rating']==4]
# Out:
#          movieId                         title                  genres  \
# 5412947    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5412948    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5412949    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5412950    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5412951    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# ...          ...                           ...                     ...
# 5415594    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415595    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415596    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415597    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
# 5415598    45499  X-Men: The Last Stand (2006)  Action|Sci-Fi|Thriller
#
#          userId  rating   timestamp  count  mean
# 5412947       7     4.0  1157949636      1   4.0
# ...

# %%
i=m[m['title']=='Jurassic Park (1993)']

# %%
i[i['rating']==5]
# Out:
#          movieId                 title                            genres  \
# 1410399      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410400      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410401      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410402      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410403      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# ...          ...                   ...                               ...
# 1466800      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466801      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466802      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466803      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466804      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#
#          userId  rating   timestamp  count  mean
# ...

# %%
i[i['rating']==4.5]
# Out:
#          movieId                 title                            genres  \
# 1411589      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1411590      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1411591      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1411592      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1411593      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# ...          ...                   ...                               ...
# 1461088      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1461089      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1461090      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1461091      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1461092      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#
#          userId  rating   timestamp  count  mean
# ...

# %%
i[i['genres']=='Sci-Fi']
# Out:
# Empty DataFrame
# Columns: [movieId, title, genres, userId, rating, timestamp, count, mean]
# Index: []

# %%
i[i['rating']==4]
# Out:
#          movieId                 title                            genres  \
# 1410161      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410162      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410163      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410164      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1410165      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# ...          ...                   ...                               ...
# 1466086      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466087      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466088      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466089      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
# 1466090      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#
#          userId  rating  timestamp  count  mean
# ...

# %% [markdown]
# ### IMPORTANT NOTE 2

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
x
# Out:
# (1, 'Forrest Gump (1994)', 4.0)

# %%
o=pd.merge(links,x,on='movieId',how='inner')
o
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 o=pd.merge(links,x,on='movieId',how='inner')
#       2 o
#
# File ~\.conda\envs\project\Lib\site-packages\pandas\core\reshape\merge.py:152, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     134 @Substitution("\nleft : DataFrame or named Series")
#     135 @Appender(_merge_doc, indents=0)
#     136 def merge(
#    (...)
#     149     validate: str | None = None,
#     150 ) -> DataFrame:
#     151     left_df = _validate_operand(left)
# --> 152     right_df = _validate_operand(right)
#     153     if how == "cross":
#     154         return _cross_merge(
#     155             left_df,
#     156             right_df,
#    (...)
#     166             copy=copy,
#     167         )
#
# ...

# %% [markdown]
# ### Mention the movieId of the movie which has the highest IMDB rating.

# %%
o.groupby('movieId')['imdbId'].max()

# %%
o[o['movieId']==1].value_counts().idxmax()

# %% [markdown]
# ## Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
n=o[o['genres']=='Action|Adventure|Comedy|Sci-Fi']

# %%
n.groupby('movieId')['imdbId'].max()

# %%
o[o['movieId']==1527].value_counts().idxmax()
