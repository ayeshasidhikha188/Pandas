# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import sklearn

# %%
gdf=pd.read_csv(r"C:\Users\mdimr\Downloads\german_credit_data_1.csv") 
gdf
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# ...

# %% [markdown]
# ### Information of german credit data

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %% [markdown]
# ### size

# %%
gdf.size
# Out:
# 10000

# %% [markdown]
# ### Shape

# %%
gdf.shape # 2D
# Out:
# (1000, 10)

# %% [markdown]
# ### Dropping unnamed column

# %%
gdf.drop(columns=['Unnamed: 0'],inplace=True)

# %%
gdf
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %% [markdown]
# ### dtypes of each column

# %%
gdf['Age'].dtype
# Out:
# dtype('int64')

# %%
gdf['Sex'].dtype
# Out:
# dtype('O')

# %%
gdf['Job'].dtype
# Out:
# dtype('O')

# %%
gdf['Housing'].dtype
# Out:
# dtype('O')

# %%
gdf['Saving accounts'].dtype
# Out:
# dtype('O')

# %%
gdf['Checking account'].dtype
# Out:
# dtype('O')

# %%
gdf['Credit amount'].dtype
# Out:
# dtype('int64')

# %%
gdf['Duration'].dtype
# Out:
# dtype('int64')

# %%
gdf['Purpose'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ###  changing Job into object dtype

# %%
gdf['Job']=gdf['Job'].astype('object')
gdf['Job']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: Job, Length: 1000, dtype: object

# %% [markdown]
# ### Finding unique values in each column

# %%
gdf.nunique()
# Out:
# Age                  53
# Sex                   2
# Job                   4
# Housing               3
# Saving accounts       4
# Checking account      3
# Credit amount       921
# Duration             33
# Purpose               8
# dtype: int64

# %%
import numpy as np

# %%
gdf.describe(include='all').T
# Out:
#                    count unique     top   freq      mean          std    min  \
# Age               1000.0    NaN     NaN    NaN    35.546    11.375469   19.0
# Sex                 1000      2    male    690       NaN          NaN    NaN
# Job               1000.0    4.0     2.0  630.0       NaN          NaN    NaN
# Housing             1000      3     own    713       NaN          NaN    NaN
# Saving accounts      817      4  little    603       NaN          NaN    NaN
# Checking account     606      3  little    274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN    NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN    NaN    20.903    12.058814    4.0
# Purpose             1000      8     car    337       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# Age                 27.0    33.0     42.0     75.0
# Sex                  NaN     NaN      NaN      NaN
# ...

# %%
gdf
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 4     53    male   2    free          little           little           4870
# ..   ...     ...  ..     ...             ...              ...            ...
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %% [markdown]
# ### All Age people with frequently observed

# %%
x=gdf['Age'].value_counts()
x
# Out:
# Age
# 27    51
# 26    50
# 23    48
# 24    44
# 28    43
# 25    41
# 30    40
# 35    40
# 36    39
# 31    38
# 29    37
# 32    34
# 33    33
# 34    32
# 37    29
# 22    27
# 40    25
# 38    24
# 42    22
# 39    21
# 46    18
# 43    17
# 47    17
# 44    17
# 41    17
# 45    15
# 20    14
# 21    14
# 49    14
# 50    12
# 48    12
# 54    10
# 57     9
# 52     9
# 51     8
# 55     8
# 63     8
# 61     7
# 53     7
# 60     6
# 65     5
# 58     5
# 64     5
# 66     5
# 74     4
# 67     3
# 68     3
# 56     3
# 59     3
# 75     2
# 19     2
# 62     2
# 70     1
# Name: count, dtype: int64

# %%
len(x)
# Out:
# 53

# %% [markdown]
# ### pie chart of all different ages

# %%
gdf['Age'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### people who are above age 60

# %%
y=gdf[gdf['Age']>50]
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# 8     61    male   1     own            rich              NaN           3059
# 13    60    male   1     own          little           little           1199
# ..   ...     ...  ..     ...             ...              ...            ...
# 955   57  female   3    rent            rich           little           1231
# 967   54  female   3    rent          little              NaN           3568
# 975   57  female   1     own      quite rich             rich           1258
# 976   64  female   2     own          little         moderate            753
# 987   64  female   2     own        moderate              NaN           1409
#
#      Duration              Purpose
# ...

# %%
len(y) # 113 people are above 50 age
# Out:
# 113

# %% [markdown]
# ### people who are below age 20

# %%
y=gdf[gdf['Age']<20]
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 391   19  female   1    rent            rich         moderate            983
# 633   19  female   2    rent          little              NaN           1980
#
#      Duration              Purpose
# 391        12  furniture/equipment
# 633         9  furniture/equipment

# %%
len(y) # 2 people are below 20
# Out:
# 2

# %% [markdown]
# ###  people who has ages in between 20 to 50

# %%
y=gdf[(gdf['Age']<=20) | (gdf['Age']<=50)]
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 2     49    male   1     own          little              NaN           2096
# 3     45    male   2    free          little           little           7882
# 5     35    male   1    free             NaN              NaN           9055
# 7     35    male   3    rent          little         moderate           6948
# ..   ...     ...  ..     ...             ...              ...            ...
# 995   31  female   1     own          little              NaN           1736
# 996   40    male   3     own          little           little           3857
# 997   38    male   2     own          little              NaN            804
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
len(y) # in between 20 to 50 ages 887
# Out:
# 887

# %% [markdown]
# ### Gender's
# ####  Count of male
# #### Count of female

# %%
x=gdf['Sex'].value_counts()
x
# Out:
# Sex
# male      690
# female    310
# Name: count, dtype: int64

# %%
gdf['Sex'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
male_data = gdf[gdf['Sex'] == 'male']
female_data = gdf[gdf['Sex'] == 'female']

# %%
female_data.count # 310
# Out:
# <bound method DataFrame.count of      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# 14    28  female   2    rent          little           little           1403
# ..   ...     ...  ..     ...             ...              ...            ...
# 976   64  female   2     own          little         moderate            753
# 982   28  female   3     own        moderate             rich           2923
# 985   25  female   2    rent          little           little           1433
# 987   64  female   2     own        moderate              NaN           1409
# 995   31  female   1     own          little              NaN           1736
#
# ...

# %% [markdown]
# ### Count of  people are doing different jobs  at a time

# %%
gdf['Job'].value_counts()
# Out:
# Job
# 2    630
# 1    200
# 3    148
# 0     22
# Name: count, dtype: int64

# %%
gdf['Job'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Count of  people are living in own , rent,free Houses

# %%
gdf['Housing'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gdf['Housing'].value_counts()
#
# NameError: name 'gdf' is not defined

# %%
gdf['Housing'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###  Count of people are having their checking account as their rich, quite rich , moderate , little

# %%
gdf['Saving accounts'].value_counts()
# Out:
# Saving accounts
# little        603
# moderate      103
# quite rich     63
# rich           48
# Name: count, dtype: int64

# %%
gdf['Saving accounts'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Count of people are having their checking account as little ,moderate,rich

# %%
gdf['Checking account'].value_counts()
# Out:
# Checking account
# little      274
# moderate    269
# rich         63
# Name: count, dtype: int64

# %%
gdf['Checking account'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Count of people who  credited amount

# %%
gdf['Credit amount'].value_counts()
# Out:
# Credit amount
# 1478    3
# 1262    3
# 1258    3
# 1275    3
# 1393    3
#        ..
# 1459    1
# 882     1
# 3758    1
# 1136    1
# 4576    1
# Name: count, Length: 921, dtype: int64

# %%
gdf['Credit amount'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
#  ### Count of people who are having Different time period

# %%
gdf['Duration'].value_counts()
# Out:
# Duration
# 24    184
# 12    179
# 18    113
# 36     83
# 6      75
# 15     64
# 9      49
# 48     48
# 30     40
# 21     30
# 10     28
# 60     13
# 27     13
# 42     11
# 11      9
# 20      8
# 8       7
# 4       6
# 45      5
# 7       5
# 39      5
# 14      4
# 13      4
# 33      3
# 28      3
# 54      2
# 16      2
# 22      2
# 47      1
# 5       1
# 26      1
# 72      1
# 40      1
# Name: count, dtype: int64

# %% [markdown]
# ### Count of people who are having time period below 1 year

# %%
x=gdf[gdf['Duration']<=12]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male   2     own             NaN           little           1169
# 2     49    male   1     own          little              NaN           2096
# 8     61    male   1     own            rich              NaN           3059
# 10    25  female   2    rent          little         moderate           1295
# 12    22  female   2     own          little         moderate           1567
# ..   ...     ...  ..     ...             ...              ...            ...
# 976   64  female   2     own          little         moderate            753
# 990   37    male   1     own             NaN              NaN           3565
# 994   50    male   2     own             NaN              NaN           2390
# 995   31  female   1     own          little              NaN           1736
# 997   38    male   2     own          little              NaN            804
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 359

# %% [markdown]
# ### Count of people who are having time period above  1year to 2year

# %%
x=gdf[(gdf['Duration']>=12) & (gdf['Duration']<=24)]
x# doubt
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49    male   1     own          little              NaN           2096
# 4     53    male   2    free          little           little           4870
# 6     53    male   2     own      quite rich              NaN           2835
# 8     61    male   1     own            rich              NaN           3059
# 10    25  female   2    rent          little         moderate           1295
# ..   ...     ...  ..     ...             ...              ...            ...
# 991   34    male   1     own        moderate              NaN           1569
# 992   23    male   1    rent             NaN           little           1936
# 994   50    male   2     own             NaN              NaN           2390
# 995   31  female   1     own          little              NaN           1736
# 997   38    male   2     own          little              NaN            804
#
#      Duration              Purpose
# ...

# %% [markdown]
# ### Count of people who are having time period above  1year to 2year

# %%
x=gdf[(gdf['Duration']>=24) & (gdf['Duration']<=36)]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# 6     53  male   2     own      quite rich              NaN           2835
# 7     35  male   3    rent          little         moderate           6948
# 9     28  male   3     own          little         moderate           5234
# ..   ...   ...  ..     ...             ...              ...            ...
# 984   30  male   1     own          little              NaN           2028
# 988   29  male   3    free          little           little           6579
# 989   48  male   1     own          little         moderate           1743
# 993   30  male   3     own          little           little           3959
# 996   40  male   3     own          little           little           3857
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 327

# %%
gdf[gdf['Duration']>36]# doubt
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 3     45    male   2    free          little           little           7882
# 11    24  female   2    rent          little           little           4308
# 29    63    male   2     own          little           little           6836
# 35    25    male   1     own          little         moderate           4746
# ..   ...     ...  ..     ...             ...              ...            ...
# 973   36    male   2    rent          little           little           7297
# 981   33    male   3    rent          little              NaN           4844
# 986   33    male   2     own          little             rich           6289
# 998   23    male   2    free          little           little           1845
# 999   27    male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
gdf['Duration'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### count of people who has different purpose

# %%
gdf['Purpose'].value_counts()
# Out:
# Purpose
# car                    337
# radio/TV               280
# furniture/equipment    181
# business                97
# education               59
# repairs                 22
# domestic appliances     12
# vacation/others         12
# Name: count, dtype: int64

# %%
gdf['Purpose'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
len(z)
# Out:
# 197

# %% [markdown]
# ### Basic statistical Operations

# %%
gdf.describe(include='all')
# Out:
#                 Age   Sex     Job Housing Saving accounts Checking account  \
# count   1000.000000  1000  1000.0    1000             817              606
# unique          NaN     2     4.0       3               4                3
# top             NaN  male     2.0     own          little           little
# freq            NaN   690   630.0     713             603              274
# mean      35.546000   NaN     NaN     NaN             NaN              NaN
# std       11.375469   NaN     NaN     NaN             NaN              NaN
# min       19.000000   NaN     NaN     NaN             NaN              NaN
# 25%       27.000000   NaN     NaN     NaN             NaN              NaN
# 50%       33.000000   NaN     NaN     NaN             NaN              NaN
# 75%       42.000000   NaN     NaN     NaN             NaN              NaN
# max       75.000000   NaN     NaN     NaN             NaN              NaN
#
#         Credit amount     Duration Purpose
# ...

# %%
gdf.describe(include='all').T
# Out:
#                    count unique     top   freq      mean          std    min  \
# Age               1000.0    NaN     NaN    NaN    35.546    11.375469   19.0
# Sex                 1000      2    male    690       NaN          NaN    NaN
# Job               1000.0    4.0     2.0  630.0       NaN          NaN    NaN
# Housing             1000      3     own    713       NaN          NaN    NaN
# Saving accounts      817      4  little    603       NaN          NaN    NaN
# Checking account     606      3  little    274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN    NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN    NaN    20.903    12.058814    4.0
# Purpose             1000      8     car    337       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# Age                 27.0    33.0     42.0     75.0
# Sex                  NaN     NaN      NaN      NaN
# ...

# %% [markdown]
# ### Count of male  who are doing 2 jobs

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Job']==2)] # 433 males who has 2 jobs
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male   2     own             NaN           little           1169
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 6     53  male   2     own      quite rich              NaN           2835
# 16    53  male   2     own             NaN              NaN           2424
# ..   ...   ...  ..     ...             ...              ...            ...
# 986   33  male   2     own          little             rich           6289
# 994   50  male   2     own             NaN              NaN           2390
# 997   38  male   2     own          little              NaN            804
# 998   23  male   2    free          little           little           1845
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 433

# %% [markdown]
# ### Count of female who are doing 2 jobs

# %%
y= gdf[(gdf['Sex'] == 'female') & (gdf['Job']==2)]
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 12    22  female   2     own          little         moderate           1567
# 14    28  female   2    rent          little           little           1403
# ..   ...     ...  ..     ...             ...              ...            ...
# 965   26  female   2     own             NaN         moderate           1715
# 974   33  female   2     own          little              NaN           2831
# 976   64  female   2     own          little         moderate            753
# 985   25  female   2    rent          little           little           1433
# 987   64  female   2     own        moderate              NaN           1409
#
#      Duration              Purpose
# ...

# %%
len(y) # females who has two jobs
# Out:
# 197

# %% [markdown]
# ### Count of male who are doing 0 jobs

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Job']==0)]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 140   27  male   0     own            rich             rich            709
# 187   68  male   0    free          little         moderate           1175
# 236   23  male   0     own             NaN         moderate          14555
# 310   40  male   0    free             NaN         moderate           5381
# 364   25  male   0     own          little           little           2473
# 438   65  male   0     own          little           little           3394
# 756   74  male   0     own          little             rich           1299
# 774   66  male   0    free      quite rich             rich           1480
# 799   35  male   0     own             NaN         moderate           1549
# 950   40  male   0     own          little         moderate           3590
#
#      Duration              Purpose
# 140         6                  car
# 187        16                  car
# 236         6                  car
# ...

# %%
len(x) # 10 males who has 0 jobs
# Out:
# 10

# %% [markdown]
# ### Count of male who are doing 0 jobs

# %%
y= gdf[(gdf['Sex'] == 'female') & (gdf['Job']==0)]
y
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 47    23  female   0    rent      quite rich           little           1352
# 300   54  female   0     own          little              NaN            672
# 347   23  female   0    rent      quite rich         moderate           3758
# 429   55  female   0    free          little           little           1190
# 439   26  female   0     own          little             rich            609
# 640   27  female   0     own          little           little            750
# 697   38  female   0     own          little              NaN            926
# 735   29  female   0     own             NaN         moderate           3990
# 804   24  female   0    rent             NaN         moderate           7472
# 809   26  female   0    rent          little         moderate           1778
# 883   65  female   0     own          little              NaN           1098
# ...

# %%
len(y) # 12 females who has 0 jobs
# Out:
# 12

# %% [markdown]
# ### count of male who are doing 3 jobs

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Job']==3)]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 7     35  male   3    rent          little         moderate           6948
# 9     28  male   3     own          little         moderate           5234
# 40    30  male   3     own      quite rich              NaN           2333
# 51    30  male   3     own          little         moderate           5965
# 56    52  male   3     own             NaN         moderate           6468
# ..   ...   ...  ..     ...             ...              ...            ...
# 947   38  male   3     own             NaN              NaN           2859
# 981   33  male   3    rent          little              NaN           4844
# 988   29  male   3    free          little           little           6579
# 993   30  male   3     own          little           little           3959
# 996   40  male   3     own          little           little           3857
#
#      Duration              Purpose
# ...

# %%
len(x) # 3 jobs males
# Out:
# 111

# %% [markdown]
# ### count of female who are doing 3 jobs

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Job']==3)]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 18    44  female   3    free          little         moderate          12579
# 34    33  female   3     own          little             rich           1474
# 45    35  female   3     own          little              NaN           1393
# 58    23  female   3     own          little             rich           1961
# 85    29  female   3     own          little              NaN           1412
# 116   30  female   3     own             NaN           little           7174
# 121   41  female   3    rent          little              NaN           3868
# 141   30  female   3     own          little         moderate           4795
# 172   34  female   3     own          little         moderate           2064
# 175   53  female   3     own             NaN              NaN           7485
# 186   74  female   3    free          little         moderate           5129
# ...

# %%
len(x) # female with 3 jobs
# Out:
# 37

# %% [markdown]
# ### count of female who are living free

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='free')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 18    44  female   3    free          little         moderate          12579
# 44    58  female   1    free          little           little           6143
# 186   74  female   3    free          little         moderate           5129
# 263   57  female   1    free          little              NaN           2748
# 292   44  female   3    free          little           little           6419
# 340   24  female   2    free          little         moderate           5743
# 374   60  female   3    free        moderate         moderate          14782
# 381   38  female   3    free          little         moderate          12976
# 396   55  female   3    free          little           little           2578
# 429   55  female   0    free          little           little           1190
# 487   62  female   2    free          little              NaN           3757
# ...

# %%
len(x) # 19 females  are living free
# Out:
# 19

# %% [markdown]
# ### count of male who are living in own houses

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='own')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 0     67  male   2     own             NaN           little           1169
# 2     49  male   1     own          little              NaN           2096
# 6     53  male   2     own      quite rich              NaN           2835
# 8     61  male   1     own            rich              NaN           3059
# 9     28  male   3     own          little         moderate           5234
# ..   ...   ...  ..     ...             ...              ...            ...
# 993   30  male   3     own          little           little           3959
# 994   50  male   2     own             NaN              NaN           2390
# 996   40  male   3     own          little           little           3857
# 997   38  male   2     own          little              NaN            804
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration              Purpose
# ...

# %%
len(x) # 519 males are living in own
# Out:
# 517

# %% [markdown]
# ### count of male who are living in rental houses

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='rent')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 7     35  male   3    rent          little         moderate           6948
# 21    44  male   2    rent      quite rich           little           2647
# 22    48  male   1    rent          little           little           2241
# 33    57  male   1    rent             NaN              NaN           1264
# 43    24  male   2    rent        moderate           little           6187
# ..   ...   ...  ..     ...             ...              ...            ...
# 968   29  male   2    rent             NaN              NaN           7166
# 973   36  male   2    rent          little           little           7297
# 979   25  male   2    rent        moderate         moderate           1264
# 981   33  male   3    rent          little              NaN           4844
# 992   23  male   1    rent             NaN           little           1936
#
#      Duration   Purpose
# 7          36       car
# ...

# %%
len(x) # 84 males are living in rent
# Out:
# 84

# %% [markdown]
# ### count of male who are living free

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='free')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 5     35  male   1    free             NaN              NaN           9055
# 36    31  male   2    free          little              NaN           6110
# 54    57  male   2    free          little         moderate           2225
# ..   ...   ...  ..     ...             ...              ...            ...
# 938   42  male   2    free          little         moderate           6288
# 946   30  male   2    free      quite rich           little           3349
# 959   30  male   2    free        moderate         moderate           3069
# 988   29  male   3    free          little           little           6579
# 998   23  male   2    free          little           little           1845
#
#      Duration              Purpose
# ...

# %%
len(x) # 89 males are living free
# Out:
# 89

# %% [markdown]
# ###  count of female who are living in own houses

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='own')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 12    22  female   2     own          little         moderate           1567
# 15    32  female   1     own        moderate           little           1282
# 34    33  female   3     own          little             rich           1474
# 45    35  female   3     own          little              NaN           1393
# ..   ...     ...  ..     ...             ...              ...            ...
# 975   57  female   1     own      quite rich             rich           1258
# 976   64  female   2     own          little         moderate            753
# 982   28  female   3     own        moderate             rich           2923
# 987   64  female   2     own        moderate              NaN           1409
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
len(x) # 519 females are living in own houses
# Out:
# 196

# %% [markdown]
# ### count of female who are living rental houses

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='rent')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 10    25  female   2    rent          little         moderate           1295
# 11    24  female   2    rent          little           little           4308
# 14    28  female   2    rent          little           little           1403
# 27    42  female   2    rent            rich             rich            409
# 47    23  female   0    rent      quite rich           little           1352
# ..   ...     ...  ..     ...             ...              ...            ...
# 952   28  female   2    rent      quite rich         moderate           4113
# 955   57  female   3    rent            rich           little           1231
# 967   54  female   3    rent          little              NaN           3568
# 972   29  female   0    rent          little           little           1193
# 985   25  female   2    rent          little           little           1433
#
#      Duration              Purpose
# ...

# %%
len(x) # 95  females are living in rent
# Out:
# 95

# %% [markdown]
# ### male  who are having own houses and saving accounts as rich

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='rich')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 8     61  male   1     own            rich              NaN           3059
# 30    36  male   2     own            rich         moderate           1913
# 67    22  male   2     own            rich         moderate           1007
# 94    54  male   2     own            rich         moderate           1318
# 136   27  male   2     own            rich              NaN           8613
# 140   27  male   0     own            rich             rich            709
# 149   46  male   2     own            rich              NaN           1582
# 183   50  male   2     own            rich              NaN           3777
# 190   54  male   3     own            rich              NaN           4591
# 209   55  male   2     own            rich              NaN           1413
# 226   27  male   2     own            rich         moderate          10961
# ...

# %%
len(x) #26 male who are rich  owning house
# Out:
# 26

# %% [markdown]
# ### females who are having own houses and saving accounts as rich

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='rich')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 167   20  female   2     own            rich         moderate           1577
# 250   39  female   1     own            rich           little            666
# 327   34  female   2     own            rich              NaN           1525
# 399   43  female   1     own            rich              NaN           1516
# 437   37  female   2     own            rich              NaN           1287
# 483   30  female   2     own            rich              NaN            960
# 592   36  female   1     own            rich              NaN           1572
# 612   29  female   2     own            rich           little           3357
# 725   41  female   1     own            rich              NaN            250
# 875   40  female   2     own            rich         moderate           1322
# 897   35  female   2     own            rich              NaN           1592
#
#      Duration              Purpose
# ...

# %%
len(x) # 11 female who are rich and  own house
# Out:
# 11

# %% [markdown]
# ### female  who are having own houses and saving accounts as little

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='little')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 12    22  female   2     own          little         moderate           1567
# 34    33  female   3     own          little             rich           1474
# 45    35  female   3     own          little              NaN           1393
# 57    31  female   2     own          little              NaN           9566
# ..   ...     ...  ..     ...             ...              ...            ...
# 953   26  female   3     own          little              NaN          10974
# 954   29  female   2     own          little           little           1893
# 974   33  female   2     own          little              NaN           2831
# 976   64  female   2     own          little         moderate            753
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
len(x) # female who are little savings
# Out:
# 127

# %% [markdown]
# ### male who are having own houses and saving accounts as little

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='little')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49  male   1     own          little              NaN           2096
# 9     28  male   3     own          little         moderate           5234
# 13    60  male   1     own          little           little           1199
# 20    48  male   2     own          little              NaN           2134
# 25    36  male   1     own          little           little           1374
# ..   ...   ...  ..     ...             ...              ...            ...
# 986   33  male   2     own          little             rich           6289
# 989   48  male   1     own          little         moderate           1743
# 993   30  male   3     own          little           little           3959
# 996   40  male   3     own          little           little           3857
# 997   38  male   2     own          little              NaN            804
#
#      Duration              Purpose
# ...

# %%
len(x) # males who  owns house and little saving
# Out:
# 303

# %% [markdown]
# ### male who are having own houses and saving accounts as moderate

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='moderate')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 23    44  male   2     own        moderate         moderate           1804
# 32    30  male   2     own        moderate         moderate           5866
# 88    30  male   3     own        moderate           little           2249
# 97    34  male   2     own        moderate         moderate           2622
# 110   31  male   2     own        moderate         moderate           1449
# 145   30  male   2     own        moderate         moderate           3566
# 156   48  male   2     own        moderate           little           1288
# 158   38  male   2     own        moderate         moderate           3512
# 160   36  male   2     own        moderate              NaN           2872
# 188   20  male   2     own        moderate           little            674
# 232   35  male   2     own        moderate              NaN           2141
# ...

# %%
len(x) # 52 males who own house with moderate savings
# Out:
# 52

# %% [markdown]
# ### female who are having own houses and saving accounts as moderate

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='moderate')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 15    32  female   1     own        moderate           little           1282
# 49    28  female   2     own        moderate              NaN           2073
# 134   21  female   2     own        moderate              NaN          10144
# 147   51  female   2     own        moderate              NaN            682
# 258   23  female   2     own        moderate              NaN           3812
# 259   57  female   1     own        moderate              NaN           1154
# 331   30  female   2     own        moderate              NaN           1864
# 332   24  female   3     own        moderate         moderate           7408
# 379   52  female   1     own        moderate              NaN            362
# 492   27  female   2     own        moderate              NaN           1237
# 523   23  female   2     own        moderate              NaN           3488
# ...

# %%
len(x) # 19 females who owns  house and with moderate savings
# Out:
# 19

# %% [markdown]
# ### female people who are having own houses and saving accounts as moderate

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Housing']=='own') & (gdf['Saving accounts']=='moderate')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 15    32  female   1     own        moderate           little           1282
# 49    28  female   2     own        moderate              NaN           2073
# 134   21  female   2     own        moderate              NaN          10144
# 147   51  female   2     own        moderate              NaN            682
# 258   23  female   2     own        moderate              NaN           3812
# 259   57  female   1     own        moderate              NaN           1154
# 331   30  female   2     own        moderate              NaN           1864
# 332   24  female   3     own        moderate         moderate           7408
# 379   52  female   1     own        moderate              NaN            362
# 492   27  female   2     own        moderate              NaN           1237
# 523   23  female   2     own        moderate              NaN           3488
# ...

# %%
len(x)
# Out:
# 19

# %% [markdown]
# #### female who are rich in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Checking account']=='rich') & (gdf['Saving accounts']=='rich')]
x
# Out:
#     Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 27   42  female   2    rent            rich             rich            409
#
#     Duration   Purpose
# 27        12  radio/TV

# %%
len(x)
# Out:
# 1

# %% [markdown]
# ### female who are moderate in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Checking account']=='moderate') & (gdf['Saving accounts']=='moderate')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 197   27  female   2    rent        moderate         moderate            951
# 332   24  female   3     own        moderate         moderate           7408
# 374   60  female   3    free        moderate         moderate          14782
# 531   28  female   2    rent        moderate         moderate           2631
# 556   28  female   2     own        moderate         moderate           2278
# 565   23  female   2    rent        moderate         moderate           1553
# 595   32  female   1     own        moderate         moderate            931
# 607   50  female   2    free        moderate         moderate           2671
# 618   21  female   2    rent        moderate         moderate           3441
# 691   25  female   1     own        moderate         moderate           2631
# 739   26  female   1    rent        moderate         moderate           4280
# ...

# %%
len(x)
# Out:
# 13

# %% [markdown]
# ### male who are little in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Checking account']=='little') & (gdf['Saving accounts']=='little')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 11    24  female   2    rent          little           little           4308
# 14    28  female   2    rent          little           little           1403
# 44    58  female   1    free          little           little           6143
# 59    23  female   1    rent          little           little           6229
# 83    58  female   1     own          little           little           1755
# ..   ...     ...  ..     ...             ...              ...            ...
# 934   23  female   2     own          little           little           1498
# 944   46  female   2    rent          little           little           1845
# 954   29  female   2     own          little           little           1893
# 972   29  female   0    rent          little           little           1193
# 985   25  female   2    rent          little           little           1433
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 68

# %% [markdown]
# ### male who are rich in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Checking account']=='rich') & (gdf['Saving accounts']=='rich')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 140   27  male   0     own            rich             rich            709
# 729   36  male   2     own            rich             rich           1275
#
#      Duration   Purpose
# 140         6       car
# 729        24  business

# %%
len(x)
# Out:
# 2

# %% [markdown]
# ### male who are moderate in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Checking account']=='moderate') & (gdf['Saving accounts']=='moderate')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 23    44  male   2     own        moderate         moderate           1804
# 32    30  male   2     own        moderate         moderate           5866
# 87    47  male   2    free        moderate         moderate          12612
# 97    34  male   2     own        moderate         moderate           2622
# 110   31  male   2     own        moderate         moderate           1449
# 145   30  male   2     own        moderate         moderate           3566
# 154   36  male   3    rent        moderate         moderate           6967
# 158   38  male   2     own        moderate         moderate           3512
# 191   34  male   1    free        moderate         moderate           3844
# 194   21  male   2    rent        moderate         moderate           3031
# 237   61  male   1    rent        moderate         moderate           2767
# ...

# %%
len(x)
# Out:
# 34

# %% [markdown]
# ### male who are little in saving and checking accounts

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Checking account']=='little') & (gdf['Saving accounts']=='little')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 3     45  male   2    free          little           little           7882
# 4     53  male   2    free          little           little           4870
# 13    60  male   1     own          little           little           1199
# 22    48  male   1    rent          little           little           2241
# 25    36  male   1     own          little           little           1374
# ..   ...   ...  ..     ...             ...              ...            ...
# 983   26  male   2     own          little           little           8229
# 988   29  male   3    free          little           little           6579
# 993   30  male   3     own          little           little           3959
# 996   40  male   3     own          little           little           3857
# 998   23  male   2    free          little           little           1845
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 151

# %% [markdown]
# ### Count of female for business purpose

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Purpose']=='business')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 11    24  female   2    rent          little           little           4308
# 73    41  female   1     own          little         moderate           5954
# 82    24  female   1    rent        moderate              NaN           1568
# 85    29  female   3     own          little              NaN           1412
# 243   27  female   2     own          little              NaN           1185
# 375   37  female   2    rent          little           little           7685
# 389   27  female   2     own          little              NaN           1449
# 439   26  female   0     own          little             rich            609
# 468   26  female   2     own          little              NaN           2764
# 491   42  female   3    free          little         moderate           8318
# 573   22  female   1     own          little           little            806
# ...

# %%
len(x)
# Out:
# 94

# %% [markdown]
# ### Count of female for car purpose

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Purpose']=='car')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 10    25  female   2    rent          little         moderate           1295
# 14    28  female   2    rent          little           little           1403
# 18    44  female   3    free          little         moderate          12579
# 44    58  female   1    free          little           little           6143
# 45    35  female   3     own          little              NaN           1393
# ..   ...     ...  ..     ...             ...              ...            ...
# 945   30  female   2     own      quite rich         moderate           8358
# 952   28  female   2    rent      quite rich         moderate           4113
# 954   29  female   2     own          little           little           1893
# 972   29  female   0    rent          little           little           1193
# 982   28  female   3     own        moderate             rich           2923
#
#      Duration Purpose
# ...

# %%
len(x) # 94 female for car
# Out:
# 94

# %% [markdown]
# ### Count of female for furniture/equipment  purpose

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Purpose']=='furniture/equipment')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 34    33  female   3     own          little             rich           1474
# 59    23  female   1    rent          little           little           6229
# 86    27  female   2     own          little         moderate           1295
# 108   30  female   2     own             NaN           little           7721
# 117   27  female   2    rent             NaN           little           2132
# ..   ...     ...  ..     ...             ...              ...            ...
# 926   21  female   2    rent          little           little           1049
# 944   46  female   2    rent          little           little           1845
# 953   26  female   3     own          little              NaN          10974
# 985   25  female   2    rent          little           little           1433
# 995   31  female   1     own          little              NaN           1736
#
#      Duration              Purpose
# ...

# %%
len(x) # 74 mem for furniture
# Out:
# 74

# %% [markdown]
# ### Count of female for education  purpose

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Purpose']=='education')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 96    61  female   2     own             NaN              NaN           2012
# 111   23  female   2    rent          little             rich            392
# 195   34  female   3     own          little         moderate           1501
# 215   39  female   1     own             NaN         moderate            932
# 221   23  female   2    rent             NaN           little           1200
# 244   35  female   1     own      quite rich              NaN           3447
# 263   57  female   1    free          little              NaN           2748
# 331   30  female   2     own        moderate              NaN           1864
# 340   24  female   2    free          little         moderate           5743
# 417   23  female   2    rent             NaN           little           8471
# 445   41  female   1    rent             NaN              NaN           1244
# ...

# %%
len(x) # 24 females for education
# Out:
# 24

# %% [markdown]
# ### Count of female for radio / TV  purpose

# %%
x= gdf[(gdf['Sex'] == 'female') & (gdf['Purpose']=='radio/TV')]
x
# Out:
#      Age     Sex Job Housing Saving accounts Checking account  Credit amount  \
# 1     22  female   2     own          little         moderate           5951
# 12    22  female   2     own          little         moderate           1567
# 15    32  female   1     own        moderate           little           1282
# 27    42  female   2    rent            rich             rich            409
# 49    28  female   2     own        moderate              NaN           2073
# ..   ...     ...  ..     ...             ...              ...            ...
# 967   54  female   3    rent          little              NaN           3568
# 974   33  female   2     own          little              NaN           2831
# 975   57  female   1     own      quite rich             rich           1258
# 976   64  female   2     own          little         moderate            753
# 987   64  female   2     own        moderate              NaN           1409
#
#      Duration   Purpose
# ...

# %%
len(x) # 85 females are applied for radio / TV
# Out:
# 85

# %% [markdown]
# ### Count of male for furniture/equipment  purpose

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Purpose']=='furniture/equipment')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 3     45  male   2    free          little           little           7882
# 6     53  male   2     own      quite rich              NaN           2835
# 24    26  male   2     own             NaN              NaN           2069
# 25    36  male   1     own          little           little           1374
# 31    27  male   2     own          little           little           4020
# ..   ...   ...  ..     ...             ...              ...            ...
# 948   43  male   1     own          little              NaN           1533
# 959   30  male   2    free        moderate         moderate           3069
# 980   49  male   2     own          little         moderate           8386
# 984   30  male   1     own          little              NaN           2028
# 993   30  male   3     own          little           little           3959
#
#      Duration              Purpose
# ...

# %%
len(x)
# Out:
# 107

# %% [markdown]
# ### Count of male for education  purpose

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Purpose']=='education')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 2     49  male   1     own          little              NaN           2096
# 5     35  male   1    free             NaN              NaN           9055
# 36    31  male   2    free          little              NaN           6110
# 68    37  male   2    free          little              NaN           1819
# 74    40  male   3     own             NaN           little           1977
# 87    47  male   2    free        moderate         moderate          12612
# 131   29  male   2     own          little           little           6887
# 157   45  male   1     own          little           little            339
# 174   26  male   2     own          little           little           3414
# 200   52  male   2     own      quite rich              NaN            936
# 203   21  male   2    rent          little           little            902
# ...

# %%
len(x) # 35 males for education
# Out:
# 35

# %% [markdown]
# ### Count of male for car purpose

# %%
x= gdf[(gdf['Sex'] == 'male') & (gdf['Purpose']=='car')]
x
# Out:
#      Age   Sex Job Housing Saving accounts Checking account  Credit amount  \
# 4     53  male   2    free          little           little           4870
# 7     35  male   3    rent          little         moderate           6948
# 9     28  male   3     own          little         moderate           5234
# 13    60  male   1     own          little           little           1199
# 20    48  male   2     own          little              NaN           2134
# ..   ...   ...  ..     ...             ...              ...            ...
# 983   26  male   2     own          little           little           8229
# 988   29  male   3    free          little           little           6579
# 994   50  male   2     own             NaN              NaN           2390
# 996   40  male   3     own          little           little           3857
# 999   27  male   2     own        moderate         moderate           4576
#
#      Duration Purpose
# 4          24     car
# ...

# %%
len(x) # male who applied for car
# Out:
# 243

# %% [markdown]
# ### Count of missing values and its percentage

# %%
missingvalues = gdf.isnull().sum()
print(missingvalues)
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
missingpercentage = (missingvalues / len(gdf)) * 100
print(missingpercentage)
# Out:
# Age                  0.0
# Sex                  0.0
# Job                  0.0
# Housing              0.0
# Saving accounts     18.3
# Checking account    39.4
# Credit amount        0.0
# Duration             0.0
# Purpose              0.0
# dtype: float64

# %% [markdown]
# ### Unique values for categorical columns

# %%
uniquevaluesjob = gdf['Job'].unique()
uniquevalueshousing = gdf['Housing'].unique()
print(uniquevaluesjob)
print(uniquevalueshousing)
# Out:
# [2 1 3 0]
# ['own' 'free' 'rent']

# %%
uniquevaluessaving = gdf['Saving accounts'].unique()
uniquevalueschecking = gdf['Checking account'].unique()
print(uniquevaluessaving)
print(uniquevalueschecking)
# Out:
# [nan 'little' 'quite rich' 'rich' 'moderate']
# ['little' 'moderate' nan 'rich']

# %%
uniquevaluespurpose = gdf['Purpose'].unique()
print(uniquevaluespurpose)
# Out:
# ['radio/TV' 'education' 'furniture/equipment' 'car' 'business'
#  'domestic appliances' 'repairs' 'vacation/others']

# %% [markdown]
# ### finding distribution for Continuous Columns

# %%
gdf.describe().T
# Out:
#                 count      mean          std    min     25%     50%      75%  \
# Age            1000.0    35.546    11.375469   19.0    27.0    33.0    42.00
# Credit amount  1000.0  3271.258  2822.736876  250.0  1365.5  2319.5  3972.25
# Duration       1000.0    20.903    12.058814    4.0    12.0    18.0    24.00
#
#                    max
# Age               75.0
# Credit amount  18424.0
# Duration          72.0

# %% [markdown]
# ### Credit Amount bar graph and distribution

# %%
y = gdf['Credit amount'].describe()
print(y)
# Out:
# count     1000.000000
# mean      3271.258000
# std       2822.736876
# min        250.000000
# 25%       1365.500000
# 50%       2319.500000
# 75%       3972.250000
# max      18424.000000
# Name: Credit amount, dtype: float64

# %%
gdf['Credit amount'].describe().plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
gdf['Credit amount'].plot(kind='kde') # normal
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Duration bar graph and distribution

# %%
y = gdf['Duration'].describe()
print(y)
# Out:
# count    1000.000000
# mean       20.903000
# std        12.058814
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        24.000000
# max        72.000000
# Name: Duration, dtype: float64

# %%
gdf['Duration'].describe().plot(kind='bar',color='green')
# Out:
# <Axes: >

# %%
gdf['Duration'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Age bar graph and distribution

# %%
y = gdf['Age'].describe()
print(y)
# Out:
# count    1000.000000
# mean       35.546000
# std        11.375469
# min        19.000000
# 25%        27.000000
# 50%        33.000000
# 75%        42.000000
# max        75.000000
# Name: Age, dtype: float64

# %%
gdf['Age'].describe().plot(kind='bar',color='blue')
# Out:
# <Axes: >

# %%
gdf['Age'].plot(kind='kde') # normal distribution
# Out:
# <Axes: ylabel='Density'>

# %%
### Distribution og german credit data

# %%
gdf.describe(include='all').T
# Out:
#                    count unique     top freq      mean          std    min  \
# Unnamed: 0        1000.0    NaN     NaN  NaN     499.5   288.819436    0.0
# Age               1000.0    NaN     NaN  NaN    35.546    11.375469   19.0
# Sex                 1000      2    male  690       NaN          NaN    NaN
# Job               1000.0    NaN     NaN  NaN     1.904     0.653614    0.0
# Housing             1000      3     own  713       NaN          NaN    NaN
# Saving accounts      817      4  little  603       NaN          NaN    NaN
# Checking account     606      3  little  274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN  NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN  NaN    20.903    12.058814    4.0
# Purpose             1000      8     car  337       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# Unnamed: 0        249.75   499.5   749.25    999.0
# ...

# %%
gdf.plot(kind='bar')
# Out:
# <Axes: >

# %%
gdf.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>
